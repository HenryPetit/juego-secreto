# %% [markdown]
# #Pharokka + Phold + Phynteny
#
# [pharokka](https://github.com/gbouras13/pharokka) is a rapid standardised annotation tool for bacteriophage genomes and metagenomes. You can read more about pharokka in the [documentation](https://pharokka.readthedocs.io/).
#
# [phold](https://github.com/gbouras13/phold) is a sensitive annotation tool for bacteriophage genomes and metagenomes using protein structural homology. You can read more about phold in the [documentation](https://phold.readthedocs.io/).
#
# phold uses the [ProstT5](https://github.com/mheinzinger/ProstT5) protein language model to translate protein amino acid sequences to the 3Di token alphabet used by [Foldseek](https://github.com/steineggerlab/foldseek). Foldseek is then used to search these against a database of 803k protein structures mostly predicted using [Colabfold](https://github.com/sokrypton/ColabFold).
#
# [phyntney](https://github.com/susiegriggo/Phynteny_transformer) uses phage synteny (the conserved gene order across phages) with a hybrid transformer/LSTM architecture to assign hypothetical phage proteins to a PHROG category.
#
# The tools are best run sequentially, as Pharokka conducts extra annotation steps like tRNA, tmRNA, CRISPR and INPHARED searches that Phold lacks (for now at least). Pharokka will also (rarely) annotate CDS that Phold can miss. Phynteny can then help annotate remaining hypothetical proteins with a PHROG category.
#
# * **Before you start, please make sure you change the runtime to T4 GPU (or any other kind of GPU if you have $$$), otherwise Phold won't be installed properly**
# * To do this, go to the top toolbar, then to Runtime -> Change runtime type -> Hardware accelerator
#
# * To run the cells, press the play button on the left side
# * Cells 1, 2 and 3 install pharokka, phold and phyntney and download the databases/models.
# * Once they have been run, you can re-run Cell 4 (to run Pharokka), Cell 5 (to run Phold) and Cell 6 (to run Phynteny) as many times as you would like

# %%
#@title 1. Install miniforge

#@markdown This cell installs miniforge

# %%bash

set -e

PYTHON_VERSION=$(python3 -c "import sys; print(f'{sys.version_info.major}.{sys.version_info.minor}')")

echo "python version ${PYTHON_VERSION}"

if [ ! -f CONDA_READY ]; then
  echo "installing miniforge"

  # miniforge 25.9.1 introduces some issue - latest as of 7 Nov 2025 - see https://github.com/gbouras13/phold/issues/106
  # issue is fixed if you use the previous release (25.3.1)
  #wget -qnc https://github.com/conda-forge/miniforge/releases/latest/download/Miniforge3-Linux-x86_64.sh
  wget -qnc https://github.com/conda-forge/miniforge/releases/download/25.3.1-0/Miniforge3-25.3.1-0-Linux-x86_64.sh
  bash Miniforge3-25.3.1-0-Linux-x86_64.sh -bfp /usr/local 2>&1 1>/dev/null
  conda config --set auto_update_conda false
  touch CONDA_READY
fi

pip install --upgrade matplotlib matplotlib-inline
# Out:
# python version 3.12
# installing miniforge
# warning  libmamba [python-3.12.11-h9e4cc4f_0_cpython] The following files were already present in the environment:
#     - bin/python
# warning  libmamba [charset-normalizer-3.4.2-pyhd8ed1ab_0] The following files were already present in the environment:
#     - bin/normalizer
# warning  libmamba [distro-1.9.0-pyhd8ed1ab_1] The following files were already present in the environment:
#     - bin/distro
# warning  libmamba [jsonpointer-3.0.0-py312h7900ff3_1] The following files were already present in the environment:
#     - bin/jsonpointer
# warning  libmamba [wheel-0.45.1-pyhd8ed1ab_1] The following files were already present in the environment:
#     - bin/wheel
# warning  libmamba [jsonpatch-1.33-pyhd8ed1ab_1] The following files were already present in the environment:
#     - bin/jsondiff
#     - bin/jsonpatch
# warning  libmamba [pip-25.1.1-pyh8b19718_0] The following files were already present in the environment:
#     - bin/pip
#     - bin/pip3
# warning  libmamba [tqdm-4.67.1-pyhd8ed1ab_1] The following files were already present in the environment:
#     - bin/tqdm
# Collecting matplotlib
#   Downloading matplotlib-3.10.9-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (52 kB)
# Collecting matplotlib-inline
#   Downloading matplotlib_inline-0.2.1-py3-none-any.whl.metadata (2.3 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.62.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (117 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.5.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (5.1 kB)
# Collecting numpy>=1.23 (from matplotlib)
#   Downloading numpy-2.4.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/site-packages (from matplotlib) (25.0)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-12.2.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.8 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Collecting python-dateutil>=2.7 (from matplotlib)
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting traitlets (from matplotlib-inline)
#   Downloading traitlets-5.14.3-py3-none-any.whl.metadata (10 kB)
# Collecting six>=1.5 (from python-dateutil>=2.7->matplotlib)
#   Downloading six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Downloading matplotlib-3.10.9-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 136.1 MB/s eta 0:00:00
# Downloading matplotlib_inline-0.2.1-py3-none-any.whl (9.5 kB)
# Downloading contourpy-1.3.3-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (362 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.62.1-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (5.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 172.5 MB/s eta 0:00:00
# Downloading kiwisolver-1.5.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 95.4 MB/s eta 0:00:00
# Downloading numpy-2.4.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 184.2 MB/s eta 0:00:00
# Downloading pillow-12.2.0-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (7.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 144.9 MB/s eta 0:00:00
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Downloading six-1.17.0-py2.py3-none-any.whl (11 kB)
# Downloading traitlets-5.14.3-py3-none-any.whl (85 kB)
# Installing collected packages: traitlets, six, pyparsing, pillow, numpy, kiwisolver, fonttools, cycler, python-dateutil, matplotlib-inline, contourpy, matplotlib
#
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.62.1 kiwisolver-1.5.0 matplotlib-3.10.9 matplotlib-inline-0.2.1 numpy-2.4.4 pillow-12.2.0 pyparsing-3.3.2 python-dateutil-2.9.0.post0 six-1.17.0 traitlets-5.14.3

# %%
#@title 2. Install pharokka and phold and phynteny

#@markdown This cell installs pharokka and phold. It will take a few minutes. Please be patient

PHAROKKA_VERSION="1.9.1"
PHOLD_VERSION="1.2.2"
PHYNTENY_VERSION="0.1.3"

# add paths
import sys
sys.path.append("/usr/local/bin")

# Update environment variables for shell usage
import os
os.environ["PATH"] = "/usr/local/bin:" + os.environ["PATH"]

# create envs
# pharokka isn't compatible with Python 3.13 (Google Colab default)
# so it needs a separate env
from pathlib import Path
flag_file = Path("PHAROKKA_PHOLD_PHYNTENY_READY")
if not flag_file.exists():
  # !conda install -y -c bioconda phold=={PHOLD_VERSION} pharokka=={PHAROKKA_VERSION} pytorch=*=cuda* phynteny_transformer=={PHYNTENY_VERSION}
  # Touch the flag file
  flag_file.touch()
# Out:
# Se truncaron las últimas líneas 5000 del resultado de transmisión.
#
#
#
#
# mkl-2025.3.1         | 119.6 MB  | :  49% 0.4912455766332491/1 [00:47<00:02,  5.70s/it]
#
#
#
#
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | :  74% 0.7371147652933459/1 [00:47<00:01,  7.01s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | :  43% 0.42881954312900245/1 [00:47<00:01,  2.58s/it]
#
#
#
#
#
#
#
#
#
#
#
# openjdk-25.0.1       | 111.6 MB  | :  27% 0.27368815109379063/1 [00:47<00:03,  4.90s/it]
#
#
#
#
#
#
#
#
#
# mmseqs2-18.8cc5c     | 126.9 MB  | :  55% 0.5533752870303118/1 [00:47<00:02,  6.46s/it]
#
#
#
#
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | :  76% 0.7574329314787493/1 [00:47<00:01,  6.46s/it]
#
#
#
#
#
#
#
#
#
#
# mkl-2025.3.1         | 119.6 MB  | :  51% 0.5129335462399297/1 [00:47<00:02,  5.93s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | :  47% 0.4683353372057365/1 [00:47<00:01,  2.58s/it]
#
#
#
#
#
#
#
#
#
#
#
# openjdk-25.0.1       | 111.6 MB  | :  30% 0.29832708438919076/1 [00:47<00:03,  4.63s/it]
#
#
#
#
#
#
#
#
#
# mmseqs2-18.8cc5c     | 126.9 MB  | :  57% 0.5745594734022712/1 [00:48<00:02,  5.99s/it]
#
#
#
#
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | :  78% 0.7803793181657473/1 [00:48<00:01,  5.80s/it]
#
#
#
#
#
#
#
#
#
#
# mkl-2025.3.1         | 119.6 MB  | :  54% 0.5352747679431972/1 [00:48<00:02,  5.51s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | :  51% 0.5076072066276759/1 [00:48<00:01,  2.84s/it]
#
#
#
#
#
#
#
#
#
#
#
# openjdk-25.0.1       | 111.6 MB  | :  32% 0.3210061025360931/1 [00:48<00:03,  4.94s/it]
#
#
#
#
#
#
#
#
#
# mmseqs2-18.8cc5c     | 126.9 MB  | :  59% 0.5940193655346525/1 [00:48<00:02,  5.80s/it]
#
#
#
#
#
#
#
#
#
#
# mkl-2025.3.1         | 119.6 MB  | :  56% 0.5615355022259853/1 [00:48<00:02,  5.01s/it]
#
#
#
#
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | :  80% 0.7996866303120761/1 [00:48<00:01,  5.89s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | :  55% 0.5459033774304366/1 [00:48<00:01,  2.77s/it]
#
#
#
#
#
#
#
#
#
# mmseqs2-18.8cc5c     | 126.9 MB  | :  62% 0.6153267157808675/1 [00:48<00:02,  5.47s/it]
#
#
#
#
#
#
#
#
#
#
#
# openjdk-25.0.1       | 111.6 MB  | :  34% 0.3421451873520329/1 [00:48<00:03,  5.20s/it]
#
#
#
#
#
#
#
#
#
#
# mkl-2025.3.1         | 119.6 MB  | :  58% 0.5834847726713006/1 [00:48<00:02,  5.21s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | :  61% 0.6051770685455377/1 [00:48<00:00,  2.35s/it]
#
#
#
#
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | :  82% 0.8181852592271449/1 [00:48<00:01,  6.41s/it]
#
#
#
#
#
#
#
#
#
# mmseqs2-18.8cc5c     | 126.9 MB  | :  64% 0.6351560995360156/1 [00:48<00:01,  5.42s/it]
#
#
#
#
#
#
#
#
#
#
#
# openjdk-25.0.1       | 111.6 MB  | :  37% 0.37196389639703414/1 [00:48<00:02,  4.56s/it]
#
#
#
#
#
#
#
#
#
#
# mkl-2025.3.1         | 119.6 MB  | :  60% 0.6041275389234425/1 [00:48<00:02,  5.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | :  65% 0.6488395817537808/1 [00:48<00:00,  2.36s/it]
#
#
#
#
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | :  84% 0.8397164502594382/1 [00:48<00:00,  5.86s/it]
#
#
#
#
#
#
#
#
#
#
#
# openjdk-25.0.1       | 111.6 MB  | :  40% 0.3968828175707911/1 [00:48<00:02,  4.39s/it]
#
#
#
#
#
#
#
#
#
# mmseqs2-18.8cc5c     | 126.9 MB  | :  65% 0.6547391555426525/1 [00:48<00:02,  6.08s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | :  69% 0.6932338689264078/1 [00:48<00:00,  2.33s/it]
#
#
#
#
#
#
#
#
#
#
# mkl-2025.3.1         | 119.6 MB  | :  63% 0.6271220127232967/1 [00:48<00:01,  4.99s/it]
#
#
#
#
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | :  86% 0.8579118229627847/1 [00:48<00:00,  6.33s/it]
#
#
#
#
#
#
#
#
#
#
#
# openjdk-25.0.1       | 111.6 MB  | :  42% 0.42026180541358543/1 [00:48<00:02,  4.57s/it]
#
#
#
#
#
#
#
#
#
# mmseqs2-18.8cc5c     | 126.9 MB  | :  69% 0.6857764518550581/1 [00:48<00:01,  4.98s/it]
#
#
#
#
#
#
#
#
#
#
# mkl-2025.3.1         | 119.6 MB  | :  65% 0.6512923402970071/1 [00:48<00:01,  4.73s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | :  74% 0.7366524574798563/1 [00:48<00:00,  2.43s/it]
#
#
#
#
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | :  88% 0.8803527826302453/1 [00:48<00:00,  5.75s/it]
#
#
#
#
#
#
#
#
#
#
# mkl-2025.3.1         | 119.6 MB  | :  68% 0.6838242947070281/1 [00:48<00:01,  4.19s/it]
#
#
#
#
#
#
#
#
#
#
#
# openjdk-25.0.1       | 111.6 MB  | :  44% 0.442660835682131/1 [00:48<00:02,  5.12s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | :  78% 0.7783635734497423/1 [00:48<00:00,  2.65s/it]
#
#
#
#
#
#
#
#
#
# mmseqs2-18.8cc5c     | 126.9 MB  | :  71% 0.7072069659755287/1 [00:48<00:01,  5.68s/it]
#
#
#
#
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | :  90% 0.8986492407374992/1 [00:48<00:00,  6.47s/it]
#
#
#
#
#
#
#
#
#
#
# mkl-2025.3.1         | 119.6 MB  | :  71% 0.7082559231193731/1 [00:48<00:01,  4.28s/it]
#
#
#
#
#
#
#
#
#
#
#
# openjdk-25.0.1       | 111.6 MB  | :  46% 0.46295995686300034/1 [00:48<00:02,  5.18s/it]
#
#
#
#
#
#
#
#
#
# mmseqs2-18.8cc5c     | 126.9 MB  | :  73% 0.727529005227699/1 [00:48<00:01,  5.47s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | :  82% 0.8169036689072976/1 [00:48<00:00,  2.89s/it]
#
#
#
#
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | :  92% 0.9216967128284047/1 [00:48<00:00,  5.79s/it]
#
#
#
#
#
#
#
#
#
#
# mkl-2025.3.1         | 119.6 MB  | :  73% 0.7322956002737662/1 [00:48<00:01,  4.25s/it]
#
#
#
#
#
#
#
#
#
#
#
# openjdk-25.0.1       | 111.6 MB  | :  49% 0.4888588356110061/1 [00:48<00:02,  4.75s/it]
#
#
#
#
#
#
#
#
#
# mmseqs2-18.8cc5c     | 126.9 MB  | :  75% 0.747974208354125/1 [00:48<00:01,  5.32s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | :  86% 0.8603222574607461/1 [00:48<00:00,  2.74s/it]
#
#
#
#
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | :  94% 0.9399931709356586/1 [00:48<00:00,  5.75s/it]
#
#
#
#
#
#
#
#
#
#
# mkl-2025.3.1         | 119.6 MB  | :  76% 0.7612999933622187/1 [00:49<00:00,  3.98s/it]
#
#
#
#
#
#
#
#
#
#
#
# openjdk-25.0.1       | 111.6 MB  | :  51% 0.5105578961836597/1 [00:49<00:02,  4.75s/it]
#
#
#
#
#
#
#
#
#
# mmseqs2-18.8cc5c     | 126.9 MB  | :  77% 0.7676804282350175/1 [00:49<00:01,  5.53s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | :  90% 0.897886654299123/1 [00:49<00:00,  2.73s/it]
#
#
#
#
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | :  96% 0.9580874582350976/1 [00:49<00:00,  5.82s/it]
#
#
#
#
#
#
#
#
#
#
# mkl-2025.3.1         | 119.6 MB  | :  79% 0.7886059309995456/1 [00:49<00:00,  3.90s/it]
#
#
#
#
#
#
#
#
#
#
#
# openjdk-25.0.1       | 111.6 MB  | :  53% 0.5321169628171347/1 [00:49<00:02,  5.08s/it]
#
#
#
#
#
#
#
#
#
# mmseqs2-18.8cc5c     | 126.9 MB  | :  79% 0.7865245009961209/1 [00:49<00:01,  5.54s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | :  94% 0.935207126482705/1 [00:49<00:00,  2.82s/it]
#
#
#
#
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | :  98% 0.9757774039189067/1 [00:49<00:00,  5.91s/it]
#
#
#
#
#
#
#
#
#
#
# mkl-2025.3.1         | 119.6 MB  | :  81% 0.8144747140243815/1 [00:49<00:00,  4.03s/it]
#
#
#
#
#
#
#
#
#
#
#
# openjdk-25.0.1       | 111.6 MB  | :  55% 0.5522760900588256/1 [00:49<00:02,  5.39s/it]
#
#
#
#
#
#
#
#
#
# mmseqs2-18.8cc5c     | 126.9 MB  | :  81% 0.809556145481914/1 [00:49<00:00,  5.24s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | :  99% 0.9932611943238328/1 [00:49<00:00,  2.42s/it]
#
#
#
#
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | :  99% 0.9937706058144381/1 [00:49<00:00,  5.84s/it]
#
#
#
#
#
#
#
#
#
#
# mkl-2025.3.1         | 119.6 MB  | :  84% 0.8395595945333134/1 [00:49<00:00,  4.27s/it]
#
#
#
#
#
#
#
#
#
# mmseqs2-18.8cc5c     | 126.9 MB  | :  84% 0.8417019166626198/1 [00:49<00:00,  4.40s/it]
#
#
#
#
#
#
#
#
#
#
#
# openjdk-25.0.1       | 111.6 MB  | :  58% 0.5830747566780757/1 [00:49<00:01,  4.73s/it]
#
#
#
#
#
#
#
#
#
#
# mkl-2025.3.1         | 119.6 MB  | :  87% 0.8680413859444964/1 [00:49<00:00,  4.16s/it]
#
#
#
#
#
#
#
#
#
#
#
# openjdk-25.0.1       | 111.6 MB  | :  61% 0.612193496027185/1 [00:49<00:01,  4.29s/it]
#
#
#
#
#
#
#
#
#
# mmseqs2-18.8cc5c     | 126.9 MB  | :  87% 0.8651030527711796/1 [00:49<00:00,  4.52s/it]
#
#
#
#
#
#
#
#
#
#
# mkl-2025.3.1         | 119.6 MB  | :  89% 0.8923423639375242/1 [00:49<00:00,  4.55s/it]
#
#
#
#
#
#
#
#
#
#
#
# openjdk-25.0.1       | 111.6 MB  | :  64% 0.6359924656875146/1 [00:49<00:01,  4.48s/it]
#
#
#
#
#
#
#
#
#
# mmseqs2-18.8cc5c     | 126.9 MB  | :  89% 0.8876420417599504/1 [00:49<00:00,  4.93s/it]
#
#
#
#
#
#
#
#
#
#
#
# openjdk-25.0.1       | 111.6 MB  | :  66% 0.6588114777735953/1 [00:49<00:01,  4.47s/it]
#
#
#
#
#
#
#
#
#
#
# mkl-2025.3.1         | 119.6 MB  | :  92% 0.9218693587032462/1 [00:49<00:00,  4.34s/it]
#
#
#
#
#
#
#
#
#
# mmseqs2-18.8cc5c     | 126.9 MB  | :  91% 0.908456736509143/1 [00:49<00:00,  5.06s/it]
#
#
#
#
#
#
#
#
#
#
#
# openjdk-25.0.1       | 111.6 MB  | :  68% 0.6820504716772113/1 [00:49<00:01,  4.48s/it]
#
#
#
#
#
#
#
#
#
#
# mkl-2025.3.1         | 119.6 MB  | :  95% 0.9465622879542259/1 [00:49<00:00,  4.34s/it]
#
#
#
#
#
#
#
#
#
# mmseqs2-18.8cc5c     | 126.9 MB  | :  93% 0.9292714312583358/1 [00:49<00:00,  5.01s/it]
#
#
#
#
#
#
#
#
#
#
#
# openjdk-25.0.1       | 111.6 MB  | :  70% 0.7045894958849352/1 [00:49<00:01,  4.64s/it]
#
#
#
#
#
#
#
#
#
#
# mkl-2025.3.1         | 119.6 MB  | :  97% 0.9712552172052057/1 [00:49<00:00,  4.45s/it]
#
#
#
#
#
#
#
#
#
# mmseqs2-18.8cc5c     | 126.9 MB  | :  96% 0.9578454500856298/1 [00:49<00:00,  4.61s/it]
#
#
#
#
#
#
#
#
#
#
#
# openjdk-25.0.1       | 111.6 MB  | :  73% 0.7278284897885512/1 [00:50<00:01,  4.56s/it]
#
#
#
#
#
#
#
#
#
#
# mkl-2025.3.1         | 119.6 MB  | :  99% 0.9938577397471079/1 [00:50<00:00,  4.59s/it]
#
#
#
#
#
#
#
#
#
# mmseqs2-18.8cc5c     | 126.9 MB  | :  98% 0.984079355302068/1 [00:50<00:00,  4.36s/it]
#
#
#
#
#
#
#
#
#
#
#
# openjdk-25.0.1       | 111.6 MB  | :  76% 0.7608670594346558/1 [00:50<00:00,  4.08s/it]
#
#
#
#
#
#
#
#
#
#
#
# openjdk-25.0.1       | 111.6 MB  | :  79% 0.7927856775673332/1 [00:50<00:00,  3.91s/it]
#
#
#
#
#
#
#
#
#
#
#
# openjdk-25.0.1       | 111.6 MB  | :  82% 0.8226043866123345/1 [00:50<00:00,  3.80s/it]
#
#
#
#
#
#
#
#
#
#
#
# openjdk-25.0.1       | 111.6 MB  | :  85% 0.8522831017181574/1 [00:50<00:00,  3.70s/it]
#
#
#
#
#
#
#
#
#
#
#
# openjdk-25.0.1       | 111.6 MB  | :  88% 0.8843417137900131/1 [00:50<00:00,  3.52s/it]
#
#
#
#
#
#
#
#
#
#
#
# openjdk-25.0.1       | 111.6 MB  | :  92% 0.9168203076794041/1 [00:50<00:00,  3.50s/it]
#
#
#
#
#
#
#
#
#
#
#
# openjdk-25.0.1       | 111.6 MB  | :  95% 0.9484589379337247/1 [00:50<00:00,  3.43s/it]
#
#
#
#
#
#
#
#
#
#
#
# openjdk-25.0.1       | 111.6 MB  | :  98% 0.9802375621272237/1 [00:50<00:00,  3.39s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | : 100% 1.0/1 [00:51<00:00,  2.42s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcudss-0.7.1.4     | 57.2 MB   | :   0% 0.0002731843954818996/1 [00:51<52:44:42, 189934.54s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcudss-0.7.1.4     | 57.2 MB   | :   7% 0.0672033612885473/1 [00:51<08:26, 542.69s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcudss-0.7.1.4     | 57.2 MB   | :  14% 0.14123633246414208/1 [00:52<03:01, 211.71s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcudss-0.7.1.4     | 57.2 MB   | :  20% 0.2032491902385333/1 [00:52<01:38, 123.03s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcudss-0.7.1.4     | 57.2 MB   | :  26% 0.26116428208069603/1 [00:52<00:58, 79.34s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcudss-0.7.1.4     | 57.2 MB   | :  32% 0.31744026754996735/1 [00:52<00:36, 53.77s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcudss-0.7.1.4     | 57.2 MB   | :  37% 0.36688664313219116/1 [00:52<00:24, 38.68s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcudss-0.7.1.4     | 57.2 MB   | :  41% 0.4125084371776684/1 [00:52<00:16, 28.53s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcudss-0.7.1.4     | 57.2 MB   | :  47% 0.47178945099724057/1 [00:52<00:10, 19.35s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcudss-0.7.1.4     | 57.2 MB   | :  52% 0.5236944861388015/1 [00:52<00:06, 14.20s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcudss-0.7.1.4     | 57.2 MB   | :  59% 0.5898051098454212/1 [00:53<00:03,  9.72s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcudss-0.7.1.4     | 57.2 MB   | :  64% 0.6436224357553554/1 [00:53<00:02,  7.49s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcudss-0.7.1.4     | 57.2 MB   | :  70% 0.6960738396878802/1 [00:53<00:01,  5.90s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcudss-0.7.1.4     | 57.2 MB   | :  76% 0.7586330662532351/1 [00:53<00:01,  4.54s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcudss-0.7.1.4     | 57.2 MB   | :  82% 0.8170945268863616/1 [00:53<00:00,  3.74s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcudss-0.7.1.4     | 57.2 MB   | :  87% 0.8698191152143683/1 [00:53<00:00,  3.25s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcudss-0.7.1.4     | 57.2 MB   | :  92% 0.9219973347514111/1 [00:53<00:00,  2.88s/it]
#
#
#
#
#
#
#
#
#
#
# mkl-2025.3.1         | 119.6 MB  | : 100% 1.0/1 [00:53<00:00,  4.59s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.10.19 | 44.1 MB   | :   0% 0.00035446419353468044/1 [00:53<42:07:27, 151701.72s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcudss-0.7.1.4     | 57.2 MB   | :  99% 0.9938448307631507/1 [00:53<00:00,  2.36s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.10.19 | 44.1 MB   | :   9% 0.08542587064185798/1 [00:53<06:44, 442.35s/it]
#
#
#
#
#
#
#
#
#
# mmseqs2-18.8cc5c     | 126.9 MB  | : 100% 1.0/1 [00:53<00:00,  4.36s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnvjitlink-12.9.86 | 29.1 MB   | :   0% 0.000536907561224224/1 [00:53<27:53:09, 100443.28s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.10.19 | 44.1 MB   | :  17% 0.17049727709018128/1 [00:54<02:32, 183.48s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnvjitlink-12.9.86 | 29.1 MB   | :  13% 0.13207926006115908/1 [00:54<04:09, 286.92s/it]
#
#
#
#
#
#
#
#
#
#
#
# openjdk-25.0.1       | 111.6 MB  | : 100% 1.0/1 [00:54<00:00,  3.39s/it]
#
#
#
#
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | : 100% 1.0/1 [00:54<00:00,  5.84s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.10.19 | 44.1 MB   | :  24% 0.2392633306359093/1 [00:54<01:23, 109.96s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnvjitlink-12.9.86 | 29.1 MB   | :  26% 0.26362161256109395/1 [00:54<01:27, 118.82s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvcc-tools-12.9 | 26.1 MB   | :   0% 0.0005983927253209385/1 [00:54<25:07:06, 90480.32s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.8.0        | 23.7 MB   | :   0% 0.0006585779700202317/1 [00:54<22:49:35, 82229.51s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.10.19 | 44.1 MB   | :  31% 0.3108650977299147/1 [00:54<00:47, 69.21s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.8.0        | 23.7 MB   | :  10% 0.1040553192631966/1 [00:54<05:27, 366.01s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvcc-tools-12.9 | 26.1 MB   | :  12% 0.11548979598694113/1 [00:54<04:51, 329.69s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnvjitlink-12.9.86 | 29.1 MB   | :  39% 0.3903317970100108/1 [00:54<00:40, 66.18s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.8.0        | 23.7 MB   | :  20% 0.20284201476623134/1 [00:54<02:04, 155.91s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvcc-tools-12.9 | 26.1 MB   | :  21% 0.21362620293957504/1 [00:54<01:57, 149.57s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnvjitlink-12.9.86 | 29.1 MB   | :  50% 0.5020085697446494/1 [00:54<00:21, 42.80s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.10.19 | 44.1 MB   | :  38% 0.37856775869503867/1 [00:54<00:29, 47.09s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.8.0        | 23.7 MB   | :  29% 0.2897743068089019/1 [00:54<01:04, 90.92s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvcc-tools-12.9 | 26.1 MB   | :  31% 0.3123610026175299/1 [00:54<00:57, 84.08s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnvjitlink-12.9.86 | 29.1 MB   | :  60% 0.6007995610099066/1 [00:54<00:11, 29.80s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.10.19 | 44.1 MB   | :  43% 0.4324463161123101/1 [00:54<00:19, 34.62s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.8.0        | 23.7 MB   | :  39% 0.3892195802819569/1 [00:54<00:33, 54.33s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvcc-tools-12.9 | 26.1 MB   | :  42% 0.418276514999336/1 [00:54<00:29, 50.56s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnvjitlink-12.9.86 | 29.1 MB   | :  71% 0.7114025186220967/1 [00:54<00:05, 20.17s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.10.19 | 44.1 MB   | :  48% 0.4849070167554428/1 [00:54<00:13, 25.65s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvcc-tools-12.9 | 26.1 MB   | :  52% 0.5188064928532536/1 [00:54<00:15, 33.04s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.8.0        | 23.7 MB   | :  48% 0.47944476217472864/1 [00:54<00:18, 36.05s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnvjitlink-12.9.86 | 29.1 MB   | :  85% 0.850998484540395/1 [00:54<00:01, 12.87s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.10.19 | 44.1 MB   | :  57% 0.5653703886878153/1 [00:54<00:07, 16.42s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvcc-tools-12.9 | 26.1 MB   | :  66% 0.6588303905783532/1 [00:54<00:06, 19.69s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.8.0        | 23.7 MB   | :  57% 0.5696699440675004/1 [00:54<00:10, 24.51s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnvjitlink-12.9.86 | 29.1 MB   | :  96% 0.9626752572750336/1 [00:54<00:00,  9.34s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvcc-tools-12.9 | 26.1 MB   | :  79% 0.7856896483463922/1 [00:54<00:02, 13.11s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.8.0        | 23.7 MB   | :  70% 0.7000683821315062/1 [00:54<00:04, 14.88s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.10.19 | 44.1 MB   | :  62% 0.6242114448145722/1 [00:54<00:04, 12.46s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.8.0        | 23.7 MB   | :  82% 0.8238810404953099/1 [00:55<00:01,  9.89s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvcc-tools-12.9 | 26.1 MB   | :  90% 0.9023762297839752/1 [00:55<00:00,  9.31s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.10.19 | 44.1 MB   | :  68% 0.677735538038309/1 [00:55<00:03,  9.65s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.8.0        | 23.7 MB   | :  96% 0.9555966344993562/1 [00:55<00:00,  6.69s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.10.19 | 44.1 MB   | :  75% 0.7500462335193838/1 [00:55<00:01,  6.82s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcudss-0.7.1.4     | 57.2 MB   | : 100% 1.0/1 [00:55<00:00,  2.36s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.10.19 | 44.1 MB   | :  83% 0.8259015709358054/1 [00:55<00:00,  4.96s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.10.19 | 44.1 MB   | :  89% 0.8897051257720479/1 [00:55<00:00,  4.27s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.10.19 | 44.1 MB   | :  98% 0.9797390309298567/1 [00:55<00:00,  3.11s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnvjitlink-12.9.86 | 29.1 MB   | : 100% 1.0/1 [00:55<00:00,  9.34s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.8.0        | 23.7 MB   | : 100% 1.0/1 [00:55<00:00,  6.69s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvcc-tools-12.9 | 26.1 MB   | : 100% 1.0/1 [00:55<00:00,  9.31s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
# libcublas-12.9.1.4   | 446.1 MB  | : 100% 1.0/1 [00:56<00:00, 10.75s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.10.19 | 44.1 MB   | : 100% 1.0/1 [00:56<00:00,  3.11s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
# libcudnn-9.10.2.21   | 502.4 MB  | : 100% 1.0/1 [01:08<00:00, 10.36s/it]
# libmagma-2.9.0       | 528.8 MB  | : 100% 1.0/1 [01:23<00:00, 11.34s/it]
#
#
#
#
#
# libcusparse-12.5.10. | 199.2 MB  | : 100% 1.0/1 [01:28<00:00,  8.28s/it]
#
#
#
#
#
#
#
# triton-3.4.0         | 180.4 MB  | : 100% 1.0/1 [01:35<00:00,  5.86s/it]
#
#
#
#
#
#
# libcusolver-11.7.5.8 | 195.6 MB  | : 100% 1.0/1 [01:43<00:00,  6.77s/it]
#
#
#
#
# libtorch-2.8.0       | 836.2 MB  | : 100% 1.0/1 [02:21<00:00, 1360.45s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.9.86   | 64.1 MB   | : 100% 1.0/1 [02:23<00:00,  2.42s/it]
#
#
#
#
#
#
#
#
#
#
# mkl-2025.3.1         | 119.6 MB  | : 100% 1.0/1 [02:27<00:00,  4.59s/it]
#
#
#
# foldseek-10.941cd33  | 410.2 MB  | : 100% 1.0/1 [02:28<00:00, 11.75s/it]
#
#
#
#
#
#
#
#
#
#
#
# openjdk-25.0.1       | 111.6 MB  | : 100% 1.0/1 [02:31<00:00,  3.39s/it]
#
#
#
#
#
#
#
#
# libcufft-11.4.1.4    | 154.6 MB  | : 100% 1.0/1 [02:33<00:00,  5.84s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcudss-0.7.1.4     | 57.2 MB   | : 100% 1.0/1 [02:35<00:00,  2.36s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libnvjitlink-12.9.86 | 29.1 MB   | : 100% 1.0/1 [02:36<00:00,  9.34s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.8.0        | 23.7 MB   | : 100% 1.0/1 [02:38<00:00,  6.69s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvcc-tools-12.9 | 26.1 MB   | : 100% 1.0/1 [02:39<00:00,  9.31s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcurand-10.3.10.19 | 44.1 MB   | : 100% 1.0/1 [02:45<00:00,  3.11s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
# mmseqs2-18.8cc5c     | 126.9 MB  | : 100% 1.0/1 [02:56<00:00,  4.36s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# done
# done
# done

# %%
#@title 3. Download pharokka phold databases

#@markdown This cell downloads the pharokka then the phold database. It will take some time (10-15 minutes probably depending on Zenodo's traffic). Please be patient. Perhaps go for a walk or have a coffee or tea.


# %%time

print("Downloading pharokka database. This will take a few minutes. Please be patient :)")
# !install_databases.py -o pharokka_db


print("Downloading phold database. This will take a few minutes. Please be patient :)")
# !phold install -d phold_db -t 8 --foldseek_gpu


print("Downloading phynteny database. This will take a few minutes. Please be patient :)")
# !install_models -o  phynteny_models
# Out:
# Downloading pharokka database. This will take a few minutes. Please be patient :)
# 2026-04-26 02:53:12.984 | INFO     | databases:instantiate_install:124 - Checking Pharokka database installation in pharokka_db.
# 2026-04-26 02:53:12.984 | INFO     | databases:check_db_installation:252 - PHROGs Database file VERSION_1_8_0 is missing.
# 2026-04-26 02:53:12.984 | INFO     | databases:check_db_installation:259 - VFDB Databases are missing.
# 2026-04-26 02:53:12.984 | INFO     | databases:check_db_installation:266 - CARD Databases are missing.
# 2026-04-26 02:53:12.984 | INFO     | databases:check_db_installation:272 - PHROGs Annotation File is missing.
# 2026-04-26 02:53:12.984 | INFO     | databases:check_db_installation:278 - INPHARED Mash Annotation File is missing.
# 2026-04-26 02:53:12.984 | INFO     | databases:check_db_installation:284 - INPHARED Mash Sketch File is missing.
# 2026-04-26 02:53:12.984 | INFO     | databases:instantiate_install:129 - Some Databases are missing.
# 2026-04-26 02:53:12.984 | INFO     | databases:instantiate_install:134 - Downloading Pharokka Databases from https://zenodo.org/record/17110353/files/pharokka_v1.8.0_databases.tar.gz.
#
# 2026-04-26 02:54:09.747 | INFO     | databases:instantiate_install:145 - Database file download OK: a63c485241b900a11989bd1821bfbb09
# 2026-04-26 02:54:09.747 | INFO     | databases:instantiate_install:151 - Extracting DB tarball: file=pharokka_db/pharokka_v1.8.0_databases.tar.gz, output=pharokka_db
# Downloading phold database. This will take a few minutes. Please be patient :)
# 2026-04-26 02:54:38.403 | INFO     | phold:install:1343 - You have specified the phold_db directory to store the Phold database and ProstT5 model
# 2026-04-26 02:54:38.403 | INFO     | phold:install:1355 - Checking that the Rostlab/ProstT5_fp16 ProstT5 model is available in phold_db
# 2026-04-26 02:54:38.406 | INFO     | phold.features.predict_3Di:get_T5_model:125 - Using device: cpu
# 2026-04-26 02:54:38.406 | INFO     | phold.features.predict_3Di:get_T5_model:131 - Loading T5 from: phold_db/Rostlab/ProstT5_fp16
# 2026-04-26 02:54:38.406 | INFO     | phold.features.predict_3Di:get_T5_model:132 - If phold_db/Rostlab/ProstT5_fp16 is not found, it will be downloaded
# 2026-04-26 02:54:38.407 | WARNING  | phold.databases.db:check_prostT5_download:356 - Model file phold_db/models--Rostlab--ProstT5_fp16/refs/main does not exist.
# 2026-04-26 02:54:38.407 | WARNING  | phold.databases.db:check_prostT5_download:356 - Model file phold_db/models--Rostlab--ProstT5_fp16/blobs/2c19eb6e3b583f52d34b903b5978d3d30b6b7682 does not exist.
# 2026-04-26 02:54:38.407 | WARNING  | phold.databases.db:check_prostT5_download:356 - Model file phold_db/models--Rostlab--ProstT5_fp16/blobs/60fe6bb247c90b8545d7b73820cd796ce6dcbd59 does not exist.
# 2026-04-26 02:54:38.407 | WARNING  | phold.databases.db:check_prostT5_download:356 - Model file phold_db/models--Rostlab--ProstT5_fp16/blobs/6fc7be92c58e238f20a6cdea5a87b123a4ad35e2 does not exist.
# 2026-04-26 02:54:38.407 | WARNING  | phold.databases.db:check_prostT5_download:356 - Model file phold_db/models--Rostlab--ProstT5_fp16/blobs/74da7b4afcde53faa570114b530c726135bdfcdb813dec3abfb27f9d44db7324 does not exist.
# 2026-04-26 02:54:38.407 | WARNING  | phold.databases.db:check_prostT5_download:356 - Model file phold_db/models--Rostlab--ProstT5_fp16/blobs/b1a9ffcef73280cc57f090ad6446b4116b574b6c75d83ccc32778282f7f00855 does not exist.
# 2026-04-26 02:54:38.407 | WARNING  | phold.databases.db:check_prostT5_download:356 - Model file phold_db/models--Rostlab--ProstT5_fp16/blobs/e9322396e6e75ecf8da41a9527e24dfa4eeea505 does not exist.
# 2026-04-26 02:54:38.407 | INFO     | phold.features.predict_3Di:get_T5_model:142 - ProstT5 not found. Downloading ProstT5 from Hugging Face
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# 2026-04-26 02:55:28.615 | INFO     | phold.features.predict_3Di:get_T5_model:174 - Rostlab/ProstT5_fp16 loaded
# 2026-04-26 02:55:29.171 | INFO     | phold:install:1366 - ProstT5 model downloaded
# 2026-04-26 02:55:29.171 | INFO     | phold.databases.db:install_database:143 - Checking Phold database installation in phold_db.
# 2026-04-26 02:55:29.172 | WARNING  | phold.databases.db:check_db_installation:430 - Phold Database file phold_db/acrs_plddt_over_70_metadata.tsv is missing
# 2026-04-26 02:55:29.172 | WARNING  | phold.databases.db:check_db_installation:439 - Phold Foldseek-GPU Database file phold_db/all_phold_structures_gpu is missing
# 2026-04-26 02:55:29.172 | INFO     | phold.databases.db:install_database:148 - Some Phold databases files are missing
# 2026-04-26 02:55:29.172 | INFO     | phold.databases.db:install_database:158 - Downloading Phold Search DB 1.36M from https://zenodo.org/records/16741548/files/phold_search_db_v_1_0_0.tar.gz
# 2026-04-26 02:55:29.185 | INFO     | phold.utils.external_tools:run_stream:56 - Started running aria2c --dir phold_db --out phold_search_db_v_1_0_0.tar.gz --max-connection-per-server=8 --allow-overwrite=true https://zenodo.org/records/16741548/files/phold_search_db_v_1_0_0.tar.gz ...
#
# 04/26 02:55:29 [NOTICE] Downloading 1 item(s)
# [#d7a2ac 64KiB/1.7GiB(0%) CN:5 DL:162KiB ETA:3h9m44s]
# [#d7a2ac 6.8MiB/1.7GiB(0%) CN:5 DL:4.8MiB ETA:6m10s]
# [#d7a2ac 51MiB/1.7GiB(2%) CN:5 DL:21MiB ETA:1m22s]
# [#d7a2ac 84MiB/1.7GiB(4%) CN:5 DL:14MiB ETA:2m]
# [#d7a2ac 87MiB/1.7GiB(4%) CN:5 DL:12MiB ETA:2m19s]
# [#d7a2ac 135MiB/1.7GiB(7%) CN:5 DL:16MiB ETA:1m39s]
# [#d7a2ac 173MiB/1.7GiB(9%) CN:5 DL:19MiB ETA:1m25s]
# [#d7a2ac 189MiB/1.7GiB(10%) CN:5 DL:20MiB ETA:1m19s]
# [#d7a2ac 256MiB/1.7GiB(14%) CN:5 DL:24MiB ETA:1m2s]
# [#d7a2ac 259MiB/1.7GiB(14%) CN:5 DL:27MiB ETA:55s]
# [#d7a2ac 260MiB/1.7GiB(14%) CN:5 DL:24MiB ETA:1m4s]
# [#d7a2ac 329MiB/1.7GiB(18%) CN:5 DL:29MiB ETA:50s]
# [#d7a2ac 385MiB/1.7GiB(21%) CN:5 DL:32MiB ETA:44s]
# [#d7a2ac 390MiB/1.7GiB(21%) CN:5 DL:32MiB ETA:43s]
# [#d7a2ac 391MiB/1.7GiB(21%) CN:5 DL:28MiB ETA:49s]
# [#d7a2ac 458MiB/1.7GiB(25%) CN:5 DL:32MiB ETA:41s]
# [#d7a2ac 514MiB/1.7GiB(28%) CN:5 DL:33MiB ETA:38s]
# [#d7a2ac 570MiB/1.7GiB(31%) CN:5 DL:35MiB ETA:35s]
# [#d7a2ac 626MiB/1.7GiB(34%) CN:5 DL:40MiB ETA:29s]
# [#d7a2ac 634MiB/1.7GiB(35%) CN:5 DL:39MiB ETA:29s]
# [#d7a2ac 665MiB/1.7GiB(36%) CN:5 DL:35MiB ETA:32s]
# [#d7a2ac 669MiB/1.7GiB(36%) CN:5 DL:31MiB ETA:36s]
# [#d7a2ac 671MiB/1.7GiB(37%) CN:5 DL:30MiB ETA:37s]
# [#d7a2ac 696MiB/1.7GiB(38%) CN:5 DL:25MiB ETA:44s]
# [#d7a2ac 702MiB/1.7GiB(38%) CN:5 DL:19MiB ETA:56s]
# [#d7a2ac 750MiB/1.7GiB(41%) CN:5 DL:18MiB ETA:56s]
# [#d7a2ac 778MiB/1.7GiB(42%) CN:5 DL:15MiB ETA:1m5s]
# [#d7a2ac 792MiB/1.7GiB(43%) CN:5 DL:17MiB ETA:58s]
# [#d7a2ac 857MiB/1.7GiB(47%) CN:5 DL:21MiB ETA:45s]
# [#d7a2ac 913MiB/1.7GiB(50%) CN:5 DL:28MiB ETA:31s]
# [#d7a2ac 0.9GiB/1.7GiB(53%) CN:5 DL:31MiB ETA:26s]
# [#d7a2ac 1.0GiB/1.7GiB(56%) CN:5 DL:38MiB ETA:20s]
# [#d7a2ac 1.0GiB/1.7GiB(59%) CN:5 DL:42MiB ETA:17s]
# [#d7a2ac 1.0GiB/1.7GiB(62%) CN:5 DL:46MiB ETA:14s]
# [#d7a2ac 1.1GiB/1.7GiB(64%) CN:5 DL:47MiB ETA:13s]
# [#d7a2ac 1.1GiB/1.7GiB(67%) CN:5 DL:47MiB ETA:12s]
# [#d7a2ac 1.2GiB/1.7GiB(70%) CN:5 DL:51MiB ETA:10s]
# [#d7a2ac 1.3GiB/1.7GiB(74%) CN:5 DL:55MiB ETA:8s]
# [#d7a2ac 1.3GiB/1.7GiB(77%) CN:5 DL:54MiB ETA:7s]
# [#d7a2ac 1.4GiB/1.7GiB(80%) CN:5 DL:54MiB ETA:6s]
# [#d7a2ac 1.4GiB/1.7GiB(83%) CN:5 DL:54MiB ETA:5s]
# [#d7a2ac 1.5GiB/1.7GiB(86%) CN:5 DL:54MiB ETA:4s]
# [#d7a2ac 1.5GiB/1.7GiB(89%) CN:5 DL:55MiB ETA:3s]
# [#d7a2ac 1.6GiB/1.7GiB(92%) CN:5 DL:56MiB ETA:2s]
# [#d7a2ac 1.6GiB/1.7GiB(94%) CN:5 DL:54MiB ETA:1s]
# [#d7a2ac 1.7GiB/1.7GiB(96%) CN:4 DL:52MiB ETA:1s]
# [#d7a2ac 1.7GiB/1.7GiB(98%) CN:2 DL:50MiB]
# [#d7a2ac 1.7GiB/1.7GiB(99%) CN:1 DL:46MiB]
#
# 04/26 02:56:21 [NOTICE] Download complete: phold_db/phold_search_db_v_1_0_0.tar.gz
#
# Download Results:
# gid   |stat|avg speed  |path/URI
# ======+====+===========+=======================================================
# d7a2ac|OK  |    34MiB/s|phold_db/phold_search_db_v_1_0_0.tar.gz
#
# Status Legend:
# (OK):download completed.
# 2026-04-26 02:56:21.979 | INFO     | phold.utils.external_tools:run_stream:73 - Done running aria2c --dir phold_db --out phold_search_db_v_1_0_0.tar.gz --max-connection-per-server=8 --allow-overwrite=true https://zenodo.org/records/16741548/files/phold_search_db_v_1_0_0.tar.gz
# 2026-04-26 02:56:26.778 | INFO     | phold.databases.db:install_database:171 - Phold database file download OK: ddbe0d94b1d94a392cfeb4ec113f4362
# 2026-04-26 02:56:26.779 | INFO     | phold.databases.db:install_database:177 - Extracting Phold database tarball: file=phold_db/phold_search_db_v_1_0_0.tar.gz, output=phold_db
# 2026-04-26 02:56:59.372 | INFO     | phold.databases.db:install_database:189 - Some Phold database files compatible with Foldseek-GPU are missing
# 2026-04-26 02:56:59.372 | INFO     | phold.databases.db:install_database:192 - Creating them
# 2026-04-26 02:56:59.373 | INFO     | phold.utils.external_tools:run:45 - Started running foldseek makepaddedseqdb phold_db/all_phold_structures phold_db/all_phold_structures_gpu ...
# 2026-04-26 02:57:19.873 | INFO     | phold.utils.external_tools:run:47 - Done running foldseek makepaddedseqdb phold_db/all_phold_structures phold_db/all_phold_structures_gpu
# Downloading phynteny database. This will take a few minutes. Please be patient :)
# /usr/local/lib/python3.12/site-packages/src/install_models.py:18: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# Creating 'models' subdirectory in specified path
# Downloading Phynteny models to: /content/phynteny_models/models
# 2026-04-26 02:57:23.593 | INFO     | src.install_models:instantiate_install:51 - Model installation directory (absolute path): /content/phynteny_models/models
# 2026-04-26 02:57:23.593 | WARNING  | src.install_models:check_db_installation:93 - Phynteny models are missing.
# 2026-04-26 02:57:23.593 | INFO     | src.install_models:instantiate_install:61 - Some models are missing.
# 2026-04-26 02:57:23.593 | INFO     | src.install_models:get_model_zenodo:325 - Models will be installed to: /content/phynteny_models/models
# 2026-04-26 02:57:23.593 | INFO     | src.install_models:get_model_zenodo:331 - Downloading tarball to: /content/phynteny_models
# 2026-04-26 02:57:23.594 | INFO     | src.install_models:get_model_zenodo:341 - Downloading Phynteny Models from https://zenodo.org/records/17336733/files/phynteny_transformer_models_2025-06-03.tar.gz.
# 2026-04-26 02:57:23.594 | DEBUG    | src.install_models:get_model_zenodo:342 - path
# 2026-04-26 02:57:23.594 | DEBUG    | src.install_models:get_model_zenodo:343 - https://zenodo.org/records/17336733/files/phynteny_transformer_models_2025-06-03.tar.gz
# 2026-04-26 02:57:24.240 | INFO     | src.install_models:download:114 - Downloading file, total size: 222.05 MB
# Progress: 100.0% (222.0/222.0 MB)
# 2026-04-26 02:57:44.918 | INFO     | src.install_models:get_model_zenodo:350 - Phynteny Models tarball download OK: 511358aca216d214b5d7ca7a57fe2250
# 2026-04-26 02:57:44.919 | INFO     | src.install_models:get_model_zenodo:357 - Extracting Phynteny Models tarball: file=phynteny_models/phynteny_transformer_models_2025-06-03.tar.gz, output=/content/phynteny_models/models
# 2026-04-26 02:57:44.919 | INFO     | src.install_models:untar:202 - Path checks: {'tarball_exists': True, 'tarball_readable': True, 'tarball_size': 232831570, 'output_exists': True, 'output_writable': True}
# 2026-04-26 02:57:46.370 | INFO     | src.install_models:untar:218 - Tarball inspection: {'status': 'success', 'file_count': 14, 'top_level_dirs': ['phynteny_transformer_models_2025-06-03'], 'sample_files': ['phynteny_transformer_models_2025-06-03', 'phynteny_transformer_models_2025-06-03/all_calibration_models.pkl', 'phynteny_transformer_models_2025-06-03/calibration_models.pkl', 'phynteny_transformer_models_2025-06-03/category_mapping.pkl', 'phynteny_transformer_models_2025-06-03/fold_10transformer.model']}
# 2026-04-26 02:57:46.371 | INFO     | src.install_models:untar:221 - Starting extraction: phynteny_models/phynteny_transformer_models_2025-06-03.tar.gz to phynteny_models/models
# 2026-04-26 02:57:47.792 | INFO     | src.install_models:untar:225 - Found 14 items in tarball
# 2026-04-26 02:57:47.792 | DEBUG    | src.install_models:untar:235 - Extracting: phynteny_transformer_models_2025-06-03
# 2026-04-26 02:57:47.792 | DEBUG    | src.install_models:untar:235 - Extracting: phynteny_transformer_models_2025-06-03/all_calibration_models.pkl
# 2026-04-26 02:57:47.795 | DEBUG    | src.install_models:untar:235 - Extracting: phynteny_transformer_models_2025-06-03/calibration_models.pkl
# 2026-04-26 02:57:47.796 | DEBUG    | src.install_models:untar:235 - Extracting: phynteny_transformer_models_2025-06-03/category_mapping.pkl
# 2026-04-26 02:57:47.796 | DEBUG    | src.install_models:untar:235 - Extracting: phynteny_transformer_models_2025-06-03/fold_10transformer.model
# 2026-04-26 02:57:47.955 | DEBUG    | src.install_models:untar:235 - Extracting: phynteny_transformer_models_2025-06-03/fold_1transformer.model
# 2026-04-26 02:57:48.125 | DEBUG    | src.install_models:untar:235 - Extracting: phynteny_transformer_models_2025-06-03/fold_2transformer.model
# 2026-04-26 02:57:48.307 | DEBUG    | src.install_models:untar:235 - Extracting: phynteny_transformer_models_2025-06-03/fold_3transformer.model
# 2026-04-26 02:57:48.508 | DEBUG    | src.install_models:untar:235 - Extracting: phynteny_transformer_models_2025-06-03/fold_4transformer.model
# 2026-04-26 02:57:48.680 | DEBUG    | src.install_models:untar:235 - Extracting: phynteny_transformer_models_2025-06-03/fold_5transformer.model
# 2026-04-26 02:57:48.851 | DEBUG    | src.install_models:untar:235 - Extracting: phynteny_transformer_models_2025-06-03/fold_6transformer.model
# 2026-04-26 02:57:49.022 | DEBUG    | src.install_models:untar:235 - Extracting: phynteny_transformer_models_2025-06-03/fold_7transformer.model
# 2026-04-26 02:57:49.193 | DEBUG    | src.install_models:untar:235 - Extracting: phynteny_transformer_models_2025-06-03/fold_8transformer.model
# 2026-04-26 02:57:49.398 | DEBUG    | src.install_models:untar:235 - Extracting: phynteny_transformer_models_2025-06-03/fold_9transformer.model
# 2026-04-26 02:57:49.576 | INFO     | src.install_models:untar:241 - Extraction completed
# 2026-04-26 02:57:49.576 | INFO     | src.install_models:untar:248 - Contents of output directory after extraction: ['phynteny_transformer_models_2025-06-03']
# 2026-04-26 02:57:49.576 | INFO     | src.install_models:untar:265 - Found potential model directories: ['phynteny_transformer_models_2025-06-03']
# 2026-04-26 02:57:49.576 | INFO     | src.install_models:untar:282 - Found 13 files to move from phynteny_models/models/phynteny_transformer_models_2025-06-03 to phynteny_models/models
# 2026-04-26 02:57:49.576 | DEBUG    | src.install_models:untar:288 - Moving phynteny_models/models/phynteny_transformer_models_2025-06-03/fold_6transformer.model to phynteny_models/models/fold_6transformer.model
# 2026-04-26 02:57:49.576 | DEBUG    | src.install_models:untar:288 - Moving phynteny_models/models/phynteny_transformer_models_2025-06-03/fold_1transformer.model to phynteny_models/models/fold_1transformer.model
# 2026-04-26 02:57:49.577 | DEBUG    | src.install_models:untar:288 - Moving phynteny_models/models/phynteny_transformer_models_2025-06-03/fold_2transformer.model to phynteny_models/models/fold_2transformer.model
# 2026-04-26 02:57:49.577 | DEBUG    | src.install_models:untar:288 - Moving phynteny_models/models/phynteny_transformer_models_2025-06-03/category_mapping.pkl to phynteny_models/models/category_mapping.pkl
# 2026-04-26 02:57:49.577 | DEBUG    | src.install_models:untar:288 - Moving phynteny_models/models/phynteny_transformer_models_2025-06-03/fold_5transformer.model to phynteny_models/models/fold_5transformer.model
# 2026-04-26 02:57:49.577 | DEBUG    | src.install_models:untar:288 - Moving phynteny_models/models/phynteny_transformer_models_2025-06-03/fold_4transformer.model to phynteny_models/models/fold_4transformer.model
# 2026-04-26 02:57:49.577 | DEBUG    | src.install_models:untar:288 - Moving phynteny_models/models/phynteny_transformer_models_2025-06-03/fold_10transformer.model to phynteny_models/models/fold_10transformer.model
# 2026-04-26 02:57:49.577 | DEBUG    | src.install_models:untar:288 - Moving phynteny_models/models/phynteny_transformer_models_2025-06-03/calibration_models.pkl to phynteny_models/models/calibration_models.pkl
# 2026-04-26 02:57:49.577 | DEBUG    | src.install_models:untar:288 - Moving phynteny_models/models/phynteny_transformer_models_2025-06-03/fold_8transformer.model to phynteny_models/models/fold_8transformer.model
# 2026-04-26 02:57:49.577 | DEBUG    | src.install_models:untar:288 - Moving phynteny_models/models/phynteny_transformer_models_2025-06-03/fold_7transformer.model to phynteny_models/models/fold_7transformer.model
# 2026-04-26 02:57:49.578 | DEBUG    | src.install_models:untar:288 - Moving phynteny_models/models/phynteny_transformer_models_2025-06-03/fold_9transformer.model to phynteny_models/models/fold_9transformer.model
# 2026-04-26 02:57:49.578 | DEBUG    | src.install_models:untar:288 - Moving phynteny_models/models/phynteny_transformer_models_2025-06-03/all_calibration_models.pkl to phynteny_models/models/all_calibration_models.pkl
# 2026-04-26 02:57:49.578 | DEBUG    | src.install_models:untar:288 - Moving phynteny_models/models/phynteny_transformer_models_2025-06-03/fold_3transformer.model to phynteny_models/models/fold_3transformer.model
# 2026-04-26 02:57:49.578 | INFO     | src.install_models:untar:295 - Successfully moved 13 files to phynteny_models/models
# 2026-04-26 02:57:49.578 | INFO     | src.install_models:untar:299 - Removing temporary directory: phynteny_models/models/phynteny_transformer_models_2025-06-03
# 2026-04-26 02:57:49.578 | INFO     | src.install_models:get_model_zenodo:363 - Keeping tarball at phynteny_models/phynteny_transformer_models_2025-06-03.tar.gz
# 2026-04-26 02:57:49.578 | INFO     | src.install_models:get_model_zenodo:367 - Installed 10 model files
# 2026-04-26 02:57:49.578 | INFO     | src.install_models:get_model_zenodo:372 - Done.
# 2026-04-26 02:57:49.578 | INFO     | src.install_models:instantiate_install:63 - Models successfully downloaded to: /content/phynteny_models/models
#
# Installation Summary:
# ---------------------
# Models directory: /content/phynteny_models/models
# Model files installed: 10
# Confidence dictionary: Installed
#
# When running phynteny_transformer, use:
#   phynteny_transformer -m /content/phynteny_models/models [other options] INPUT_FILE
# CPU times: user 723 ms, sys: 172 ms, total: 895 ms
# Wall time: 4min 40s

# %%
refs = [
    "/content/NC_019913.1.fasta",
    "/content/NC_019918.1.fasta",
    "/content/NC_073619.1.fasta",
    "/content/NC_073620.1.fasta",
    "/content/PQ859844.1.fasta",
]

db = "/content/pharokka_db"
pharokka_exec = "/usr/local/bin/pharokka.py"

for f in refs:
    base = f.split("/")[-1].replace(".fasta", "")
    prefix = base.replace(".", "_")
    outdir = f"/content/{prefix}_reoriented"

    print(f"\nProcesando {base} ...")
    get_ipython().system(
        f'"{pharokka_exec}" '
        f'-i "{f}" '
        f'-o "{outdir}" '
        f'-p "{prefix}" '
        f'-d "{db}" '
        f'--dnaapler '
        f'--fast '
        f'-f'
    )

print("\nListo.")
# Out:
# Procesando NC_019913.1 ...
# 2026-04-26 02:58:39.443 | INFO     | input_commands:instantiate_dirs:215 - --force was specified even though the output directory /content/NC_019913_1_reoriented does not already exist. Continuing.
# 2026-04-26 02:58:39.448 | INFO     | __main__:main:95 - Starting Pharokka v1.9.1
# 2026-04-26 02:58:39.448 | INFO     | __main__:main:96 - Command executed: Namespace(infile='/content/NC_019913.1.fasta', outdir='/content/NC_019913_1_reoriented', database='/content/pharokka_db', threads='1', force=True, prefix='NC_019913_1', locustag='Default', gene_predictor='default', meta=False, split=False, coding_table='11', evalue='1E-05', fast=True, mmseqs2_only=False, meta_hmm=False, dnaapler=True, custom_hmm='', genbank=False, terminase=False, terminase_strand='nothing', terminase_start='nothing', skip_extra_annotations=False, skip_mash=False, minced_args='', mash_distance=0.2, trna_scan_model='general', keep_raw_prodigal=False, reverse_mmseqs2=False, sensitivity=8.5, citation=False)
# 2026-04-26 02:58:39.449 | INFO     | __main__:main:97 - Repository homepage is https://github.com/gbouras13/pharokka
# 2026-04-26 02:58:39.449 | INFO     | __main__:main:98 - Written by George Bouras: george.bouras@adelaide.edu.au
# 2026-04-26 02:58:39.449 | INFO     | __main__:main:100 - Checking database installation in /content/pharokka_db.
# 2026-04-26 02:58:39.449 | INFO     | __main__:main:103 - All databases have been successfully checked.
# 2026-04-26 02:58:39.449 | INFO     | __main__:main:119 - Checking dependencies.
# 2026-04-26 02:58:39.551 | INFO     | input_commands:check_dependencies:422 - Phanotate version found is v1.6.7
# 2026-04-26 02:58:39.551 | INFO     | input_commands:check_dependencies:431 - Phanotate version is ok.
# 2026-04-26 02:58:39.586 | INFO     | input_commands:check_dependencies:489 - MMseqs2 version found is v18.8cc5c
# 2026-04-26 02:58:39.586 | INFO     | input_commands:check_dependencies:492 - MMseqs2 version is ok.
# 2026-04-26 02:58:39.716 | INFO     | input_commands:check_dependencies:516 - tRNAscan-SE version found is v2.0.12
# 2026-04-26 02:58:39.717 | INFO     | input_commands:check_dependencies:527 - tRNAscan-SE version is ok.
# 2026-04-26 02:58:39.955 | INFO     | input_commands:check_dependencies:551 - MinCED version found is v0.4.2
# 2026-04-26 02:58:39.955 | INFO     | input_commands:check_dependencies:562 - MinCED version is ok.
# 2026-04-26 02:58:39.961 | INFO     | input_commands:check_dependencies:588 - ARAGORN version found is v1.2.41
# 2026-04-26 02:58:39.961 | INFO     | input_commands:check_dependencies:599 - ARAGORN version is ok.
# 2026-04-26 02:58:39.981 | INFO     | input_commands:check_dependencies:616 - mash version found is v2.3
# 2026-04-26 02:58:39.981 | INFO     | input_commands:check_dependencies:623 - mash version is ok.
# 2026-04-26 02:58:40.669 | INFO     | input_commands:check_dependencies:642 - Dnaapler version found is v1.3.0
# 2026-04-26 02:58:40.669 | INFO     | input_commands:check_dependencies:651 - Dnaapler version is ok.
# 2026-04-26 02:58:40.669 | INFO     | input_commands:check_dependencies:663 - Pyrodigal version is v3.7.1
# 2026-04-26 02:58:40.669 | INFO     | input_commands:check_dependencies:664 - Pyrodigal version is ok.
# 2026-04-26 02:58:40.670 | INFO     | input_commands:check_dependencies:676 - Pyrodigal_gv version is v0.3.2
# 2026-04-26 02:58:40.670 | INFO     | input_commands:check_dependencies:677 - Pyrodigal_gv version is ok.
# 2026-04-26 02:58:40.670 | INFO     | input_commands:check_dependencies:689 - Pyrodigal_rv version is v0.1.0
# 2026-04-26 02:58:40.670 | INFO     | input_commands:check_dependencies:690 - Pyrodigal_rv version is ok.
# 2026-04-26 02:58:40.670 | INFO     | input_commands:validate_fasta:254 - Checking input /content/NC_019913.1.fasta.
# 2026-04-26 02:58:40.671 | INFO     | input_commands:validate_fasta:256 - Input /content/NC_019913.1.fasta is in FASTA format.
# 2026-04-26 02:58:40.671 | INFO     | input_commands:validate_fasta:261 - Checking input /content/NC_019913.1.fasta for duplicate FASTA headers.
# 2026-04-26 02:58:40.671 | INFO     | input_commands:validate_fasta:263 - All headers in /content/NC_019913.1.fasta are unique.
# 2026-04-26 02:58:40.671 | INFO     | input_commands:validate_gene_predictor:292 - Phanotate will be used for gene prediction.
# 2026-04-26 02:58:40.671 | INFO     | __main__:main:155 - You have chosen to reorient your contigs by specifying --dnaapler. Checking the input.
# 2026-04-26 02:58:40.672 | INFO     | processes:run_dnaapler:1145 - Running Dnaapler to rerorient all contigs to begin with the terminase large subunit.
# 2026-04-26 02:58:40.672 | INFO     | external_tools:run:50 - Started running dnaapler phage -o /content/NC_019913_1_reoriented/dnaapler -t 1 -i /content/NC_019913.1.fasta ...
# 2026-04-26 02:58:50.792 | INFO     | external_tools:run:52 - Done running dnaapler phage -o /content/NC_019913_1_reoriented/dnaapler -t 1 -i /content/NC_019913.1.fasta
# 2026-04-26 02:58:50.792 | INFO     | __main__:main:256 - You have specified --fast or --hmm_only. MMseqs2 will not be run.
# 2026-04-26 02:58:50.793 | INFO     | __main__:main:281 - Running Phanotate.
# 2026-04-26 02:58:50.793 | INFO     | external_tools:run:50 - Started running phanotate.py -f fasta -o /content/NC_019913_1_reoriented/phanotate_out_tmp.fasta /content/NC_019913_1_reoriented/dnaapler/dnaapler_reoriented.fasta ...

# %%
#@title 4. Run Pharokka

#@markdown First, upload your phage(s) as a nucleotide input FASTA file

#@markdown Click on the folder icon to the left and use the file upload button.

#@markdown Once it is uploaded, write the file name in the INPUT_FILE field on the right.

#@markdown Then provide a directory for pharokka's output using PHAROKKA_OUT_DIR.
#@markdown The default is 'output_pharokka'.

#@markdown Then type in a gene prediction tool for pharokka.
#@markdown Please choose either 'phanotate', 'prodigal', or 'prodigal-gv'.

#@markdown You can also provide a prefix for your output files with PHAROKKA_PREFIX.
#@markdown If you provide nothing it will default to 'pharokka'.

#@markdown You can also provide a locus tag for your output files.
#@markdown If you provide nothing it will generate a random locus tag.

#@markdown You can click FAST to turn off --fast.
#@markdown By default it is True so that Pharokka runs faster in the Colab environment.

#@markdown You can click META to turn on --meta if you have multiple phages in your input.

#@markdown You can click META_HMM to turn on --meta_hmm.

#@markdown You can click FORCE to overwrite the output directory.
#@markdown This may be useful if your earlier pharokka run has crashed for whatever reason.

#@markdown The results of Pharokka will be in the folder icon on the left hand panel.
#@markdown Additionally, it will be zipped so you can download the whole directory.

#@markdown The file to download is PHAROKKA_OUT_DIR.zip, where PHAROKKA_OUT_DIR is what you provided

#@markdown If you do not see the output directory,
#@markdown refresh the window by either clicking the folder with the refresh icon below "Files"
#@markdown or double click and select "Refresh".


# %%time
import os
import sys
import subprocess
import zipfile
INPUT_FILE = '' #@param {type:"string"}

if os.path.exists(INPUT_FILE):
    print(f"Input file {INPUT_FILE} exists")
else:
    print(f"Error: File {INPUT_FILE} does not exist")
    print(f"Please check the spelling and that you have uploaded it correctly")
    sys.exit(1)

PHAROKKA_OUT_DIR = 'output_pharokka'  #@param {type:"string"}
GENE_PREDICTOR = 'phanotate'  #@param {type:"string"}
allowed_gene_predictors = ['phanotate', 'prodigal', 'prodigal-gv']
# Check if the input parameter is valid
if GENE_PREDICTOR.lower() not in allowed_gene_predictors:
    raise ValueError("Invalid GENE_PREDICTOR. Please choose from: 'phanotate', 'prodigal', 'prodigal-gv'.")

PHAROKKA_PREFIX = 'pharokka'  #@param {type:"string"}
LOCUS_TAG = 'Default'  #@param {type:"string"}
FAST = True  #@param {type:"boolean"}
META = False  #@param {type:"boolean"}
META_HMM = False  #@param {type:"boolean"}
FORCE = True  #@param {type:"boolean"}


# Construct the command
# need to suppress PYTHONWARNINGS for phanotate version handling
command = (
    f'pharokka.py -d pharokka_db -i {INPUT_FILE} -t 4 '
    f'-o {PHAROKKA_OUT_DIR} -p {PHAROKKA_PREFIX} -l {LOCUS_TAG} -g {GENE_PREDICTOR}'
)

if FORCE is True:
  command = f"{command} -f"

if FAST is True:
  command = f"{command} --fast"

if META is True:
  command = f"{command} -m"

if META_HMM is True:
  command = f"{command} --meta_hmm"

# Execute the command
try:
    print("Running pharokka")
    subprocess.run(command, shell=True, check=True)
    print("pharokka completed successfully.")
    print(f"Your output is in {PHAROKKA_OUT_DIR}.")
    print(f"Zipping the output directory so you can download it all in one go.")

    zip_filename = f"{PHAROKKA_OUT_DIR}.zip"

    # Zip the contents of the output directory
    with zipfile.ZipFile(zip_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
        for root, dirs, files in os.walk(PHAROKKA_OUT_DIR):
            for file in files:
                zipf.write(os.path.join(root, file), os.path.relpath(os.path.join(root, file), PHAROKKA_OUT_DIR))
    print(f"Output directory has been zipped to {zip_filename}")


except subprocess.CalledProcessError as e:
    print(f"Error occurred: {e}")
# Out:
# Input file SAOMS1.fasta exists
# Running pharokka
# pharokka completed successfully.
# Your output is in output_pharokka.
# Zipping the output directory so you can download it all in one go.
# Output directory has been zipped to output_pharokka.zip
# CPU times: user 75.6 ms, sys: 3.47 ms, total: 79.1 ms
# Wall time: 1min 42s

# %%
#@title 5. Run phold

#@markdown This cell will run phold on the output of cell 3's Pharokka run

#@markdown You do not need to provide any further input files

#@markdown You can now provide a directory for phold's output with PHOLD_OUT_DIR.
#@markdown The default is 'output_phold'.

#@markdown You can also provide a prefix for your output files with PHOLD_PREFIX.
#@markdown If you provide nothing it will default to 'phold'.

#@markdown You can click FORCE to overwrite the output directory with .
#@markdown This may be useful if your earlier phold run has crashed for whatever reason.

#@markdown If your input has multiple phages, you can click SEPARATE.
#@markdown This will output separate GenBank files in the output directory.

#@markdown The results of Phold will be in the folder icon on the left hand panel.
#@markdown Additionally, it will be zipped so you can download the whole directory.

#@markdown The file to download is PHOLD_OUT_DIR.zip, where PHOLD_OUT_DIR is what you provided

#@markdown If you do not see the output directory,
#@markdown refresh the window by either clicking the folder with the refresh icon below "Files"
#@markdown or double click and select "Refresh".


# %%time
import os
import subprocess
import zipfile

# phold input is pharokka output
PHOLD_INPUT = f"{PHAROKKA_OUT_DIR}/{PHAROKKA_PREFIX}.gbk"
PHOLD_OUT_DIR = 'output_phold'  #@param {type:"string"}
PHOLD_PREFIX = 'phold'  #@param {type:"string"}
FORCE = True  #@param {type:"boolean"}
SEPARATE = False  #@param {type:"boolean"}

# Construct the command
command = f"phold run -i {PHOLD_INPUT} -t 4 -o {PHOLD_OUT_DIR} -p {PHOLD_PREFIX} -d phold_db --foldseek_gpu"

if FORCE is True:
  command = f"{command} -f"
if SEPARATE is True:
  command = f"{command} --separate"


# Execute the command
try:
    print("Running phold")
    subprocess.run(command, shell=True, check=True)
    print("phold completed successfully.")
    print(f"Your output is in {PHOLD_OUT_DIR}.")
    print(f"Zipping the output directory so you can download it all in one go.")

    zip_filename = f"{PHOLD_OUT_DIR}.zip"

    # Zip the contents of the output directory
    with zipfile.ZipFile(zip_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
        for root, dirs, files in os.walk(PHOLD_OUT_DIR):
            for file in files:
                zipf.write(os.path.join(root, file), os.path.relpath(os.path.join(root, file), PHOLD_OUT_DIR))
    print(f"Output directory has been zipped to {zip_filename}")


except subprocess.CalledProcessError as e:
    print(f"Error occurred: {e}")

# %%
#@title 6. Run Phynteny

#@markdown This cell will run phynteny on the output of cell 5's Phold run to predict the function of remaining hypothetical proteins

#@markdown You do not need to provide any further input files

#@markdown You can now provide a directory for phynteny's output with PHYNTENY_OUT_DIR.
#@markdown The default is 'output_phynteny'.

#@markdown You can click FORCE to overwrite the output directory with .
#@markdown This may be useful if your phynteny run has crashed for whatever reason.

#@markdown The results of Phynteny will be in the folder icon on the left hand panel.
#@markdown Additionally, it will be zipped so you can download the whole directory.

#@markdown The file to download is PHYNTENY_OUT_DIR.zip, where PHYNTENY_OUT_DIR is what you provided

#@markdown If you do not see the output directory,
#@markdown refresh the window by either clicking the folder with the refresh icon below "Files"
#@markdown or double click and select "Refresh".


# %%time
import os
import subprocess
import zipfile

# phynteny input is pharokka output
PHYNTENY_INPUT = f"{PHOLD_OUT_DIR}/{PHOLD_PREFIX}.gbk"
PHYNTENY_OUT_DIR = 'output_phynteny'  #@param {type:"string"}
FORCE = False  #@param {type:"boolean"}

# Construct the command
command = f"phynteny_transformer -m  /content/phynteny_models/models -o {PHYNTENY_OUT_DIR} {PHYNTENY_INPUT}"
if FORCE is True:
  command = f"{command} -f"


# Execute the command
try:
    print("Running phynteny")
    subprocess.run(command, shell=True, check=True)
    print("phynteny completed successfully.")
    print(f"Your output is in {PHYNTENY_OUT_DIR}.")
    print(f"Zipping the output directory so you can download it all in one go.")

    zip_filename = f"{PHYNTENY_OUT_DIR}.zip"

    # Zip the contents of the output directory
    with zipfile.ZipFile(zip_filename, 'w', zipfile.ZIP_DEFLATED) as zipf:
        for root, dirs, files in os.walk(PHYNTENY_OUT_DIR):
            for file in files:
                zipf.write(os.path.join(root, file), os.path.relpath(os.path.join(root, file), PHYNTENY_OUT_DIR))
    print(f"Output directory has been zipped to {zip_filename}")


except subprocess.CalledProcessError as e:
    print(f"Error occurred: {e}")
